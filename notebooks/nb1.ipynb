# %%
import pandas as pd

# %%
df = pd.read_parquet('/home/tb24/projects/lakehouse/data/2018/fhv_tripdata_2018-08.parquet')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22120593 entries, 0 to 22120592
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   dispatching_base_num    object
#  1   pickup_datetime         datetime64[us]
#  2   dropOff_datetime        datetime64[us]
#  3   PUlocationID            float64
#  4   DOlocationID            float64
#  5   SR_Flag                 float64
#  6   Affiliated_base_number  object
# dtypes: datetime64[us](2), float64(3), object(2)
# memory usage: 1.2+ GB
