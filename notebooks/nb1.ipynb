# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("example").getOrCreate()
df = spark.read.parquet(
    "/home/tb24/projects/lakehouse/data/2018/fhv_tripdata_2018-08.parquet"
)
df.printSchema()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/25 22:42:11 WARN Utils: Your hostname, tb24-workstation, resolves to a loopback address: 127.0.1.1; using 192.168.1.51 instead (on interface enp7s0)
# 25/11/25 22:42:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/25 22:42:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# root
#  |-- dispatching_base_num: string (nullable = true)
#  |-- pickup_datetime: timestamp_ntz (nullable = true)
#  |-- dropOff_datetime: timestamp_ntz (nullable = true)
#  |-- PUlocationID: double (nullable = true)
# ...

# %%
import boto3
from botocore.client import Config

# Replace these with your MinIO credentials + endpoint
access_key = "YOUR_ROOT_ACCESS_KEY"
secret_key = "YOUR_ROOT_SECRET_KEY"
endpoint = "http://localhost:9000"            # your MinIO endpoint
bucket_name = "your-bucket"

# Create client
s3 = boto3.client(
    "s3",
    aws_access_key_id = access_key,
    aws_secret_access_key = secret_key,
    endpoint_url = endpoint,
    config = Config(signature_version = "s3v4"),
    # region_name = "us-east-1",   # optional, some setups require it
    # verify=False                # if using HTTP or self-signed certs
)

# Example: list buckets
response = s3.list_buckets()
print("Buckets:", [b["Name"] for b in response.get("Buckets", [])])
